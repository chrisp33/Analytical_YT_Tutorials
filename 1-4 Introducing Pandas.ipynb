# %% [markdown]
# # Data Analysis with Pandas

# %%
import pandas as pd

# %%
# reading data
data = pd.read_csv(r'Data/mass_spec_data.csv',
                   sep = ',', 
                   index_col='mz',
                   skiprows=0,
                   )

# %% [markdown]
# ## Dataframe attributes and methods

# %%
data.head()
# Out:
#      A Lwoffi 3  A Lwoffi 5  A Lwoffi 6  A Lwoffi 7  A Lwoffi 8  A Lwoffi 9  \
# mz
# 400   64.542277  196.985290  111.099422  193.239115  164.586410   86.882368
# 401   58.610715  121.227780  100.382364  135.303016  127.616293   82.222693
# 402   80.136525   92.630087   76.602382   93.846652   74.335609  119.522708
# 403   56.869512   70.038924   75.324056   52.626897   76.289193   64.901189
# 404   62.018397  135.189015   69.381468   66.582620   94.173711   87.604766
#
#      A Baumannii 1  A Baumannii 2  A Baumannii 3  A Baumannii 4  ...  \
# mz                                                               ...
# 400      28.211774      25.216104      35.445999      65.910347  ...
# 401      19.256189      13.820168      39.191268      57.776281  ...
# 402      15.652877      14.048053      32.688726      33.184871  ...
# 403      23.918820      17.699727      57.921357      70.681613  ...
# 404      17.379765      20.037537      47.477819      58.891317  ...
#
# ...

# %%
# Examine columns
data.columns
# Out:
# Index(['A Lwoffi 3', 'A Lwoffi 5', 'A Lwoffi 6', 'A Lwoffi 7', 'A Lwoffi 8',
#        'A Lwoffi 9', 'A Baumannii 1', 'A Baumannii 2', 'A Baumannii 3',
#        'A Baumannii 4', 'A Baumannii 5', 'A Baumannii 6', 'E Faecalis 1',
#        'E Faecalis 2', 'E Faecalis 3', 'E Faecalis 4', 'E Faecalis 5',
#        'E Faecalis 6', 'E Faecium 6', 'E Faecium 7', 'E Faecium 8',
#        'E Faecium 9', 'E Faecium 10', 'E Faecium 11', 'P Aeruginosa 2',
#        'P Aeruginosa 3', 'P Aeruginosa 5', 'P Aeruginosa 6', 'P Aeruginosa 7',
#        'P Aeruginosa 8', 'E Coli 1', 'E Coli 2', 'E Coli 3', 'E Coli 4',
#        'E Coli 6', 'E Coli 7', 'S Aureus 2', 'S Aureus 3', 'S Aureus 5',
#        'S Aureus 6', 'S Aureus 8', 'S Aureus 10', 'S Epidermidis 1',
#        'S Epidermidis 2', 'S Epidermidis 3', 'S Epidermidis 4',
#        'S Epidermidis 5', 'S Epidermidis 6', 'S Agalactiae 5',
#        'S Agalactiae 6', 'S Agalactiae 7', 'S Agalactiae 8', 'S Agalactiae 9',
#        'S Agalactiae 10'],
# ...

# %%
# Examine index
data.index
# Out:
# Index([400, 401, 402, 403, 404, 405, 406, 407, 408, 409,
#        ...
#        791, 792, 793, 794, 795, 796, 797, 798, 799, 800],
#       dtype='int64', name='mz', length=401)

# %%
data.describe()
# Out:
#         A Lwoffi 3   A Lwoffi 5   A Lwoffi 6   A Lwoffi 7   A Lwoffi 8  \
# count   401.000000   401.000000   401.000000   401.000000   401.000000
# mean    100.733452   100.733452   100.733452   100.733452   100.733452
# std     151.392459   168.007444   200.302025   185.805975   173.608831
# min      27.021686    20.886056    16.531951    18.492126    18.321469
# 25%      44.013196    45.024266    34.514026    42.091860    40.343170
# 50%      60.127775    59.223445    48.515670    53.646165    53.994792
# 75%      97.820051    84.182068    78.800038    81.717619    83.305631
# max    1504.621220  1546.432943  1723.934820  1638.586267  1592.820681
#
#         A Lwoffi 9  A Baumannii 1  A Baumannii 2  A Baumannii 3  \
# count   401.000000     401.000000     401.000000     401.000000
# mean    100.733452     100.733452     100.733452     100.733452
# std     187.396181     268.646767     211.272181     220.036981
# min      18.549724       9.866713      11.779554       8.938025
# ...

# %%
data.dtypes[:5]
# Out:
# A Lwoffi 3    float64
# A Lwoffi 5    float64
# A Lwoffi 6    float64
# A Lwoffi 7    float64
# A Lwoffi 8    float64
# dtype: object

# %%
# Filter by datatype
data.select_dtypes(include = float)
# Out:
#      A Lwoffi 3  A Lwoffi 5  A Lwoffi 6  A Lwoffi 7  A Lwoffi 8  A Lwoffi 9  \
# mz
# 400   64.542277  196.985290  111.099422  193.239115  164.586410   86.882368
# 401   58.610715  121.227780  100.382364  135.303016  127.616293   82.222693
# 402   80.136525   92.630087   76.602382   93.846652   74.335609  119.522708
# 403   56.869512   70.038924   75.324056   52.626897   76.289193   64.901189
# 404   62.018397  135.189015   69.381468   66.582620   94.173711   87.604766
# ..          ...         ...         ...         ...         ...         ...
# 796  135.533054   20.886056   28.310951   34.972771   29.340404   42.084339
# 797  135.694191   36.589458   30.656421   20.003576   33.282661   45.350540
# 798   72.891406   44.308839   24.565288   21.564787   28.049989   65.104958
# 799  133.098666   46.566940   40.780008   31.368721   35.446614   63.602389
# 800  134.622283   50.707227   51.923313   21.562235   46.568772   44.483303
#
# ...

# %% [markdown]
# <!-- Selecting data -->

# %% [markdown]
# ## Selecting data

# %%
data['A Baumannii 1'].head()
# Out:
# mz
# 400    28.211774
# 401    19.256189
# 402    15.652877
# 403    23.918820
# 404    17.379765
# Name: A Baumannii 1, dtype: float64

# %%
# iloc - index based selection
# df.iloc(rows, cols)

data.iloc[0:100, 20] # 100 rows, columns index = 20
# Out:
# mz
# 400    106.267004
# 401     78.470720
# 402     94.565485
# 403     55.892090
# 404     45.190349
#           ...
# 495     69.832233
# 496     61.181419
# 497     43.377039
# 498     99.334582
# 499     62.592733
# Name: E Faecium 8, Length: 100, dtype: float64

# %%
# loc - name based indexing 
data.loc[:, 'A Baumannii 1': 'A Baumannii']

# %%
data.iloc()
# Out:
#      A Lwoffi 3  A Lwoffi 5  A Lwoffi 6  A Lwoffi 7  A Lwoffi 8  A Lwoffi 9  \
# mz
# 400   64.542277  196.985290  111.099422  193.239115  164.586410   86.882368
# 401   58.610715  121.227780  100.382364  135.303016  127.616293   82.222693
# 402   80.136525   92.630087   76.602382   93.846652   74.335609  119.522708
# 403   56.869512   70.038924   75.324056   52.626897   76.289193   64.901189
# 404   62.018397  135.189015   69.381468   66.582620   94.173711   87.604766
# ..          ...         ...         ...         ...         ...         ...
# 796  135.533054   20.886056   28.310951   34.972771   29.340404   42.084339
# 797  135.694191   36.589458   30.656421   20.003576   33.282661   45.350540
# 798   72.891406   44.308839   24.565288   21.564787   28.049989   65.104958
# 799  133.098666   46.566940   40.780008   31.368721   35.446614   63.602389
# 800  134.622283   50.707227   51.923313   21.562235   46.568772   44.483303
#
# ...
